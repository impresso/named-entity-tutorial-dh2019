# %% [markdown]
# # Named Entity Linking
#
# - what is NEL and what systems we are going to use
# - limitations of these systems

# %% [markdown]
# ## Imports

# %%
import os
import json
import codecs
import numpy as np

# %% [markdown]
# ## Data loader functions

# %%
import os
import codecs

# loads raw text files from the impresso dataset
# into a dictionary where keys are filenames and
# values are the actual documents
def load_impresso_data():
    
    data_dir = "../datasets/impresso/raw/"
    docs = {}
    
    for filename in os.listdir(data_dir):
        if ".txt" not in filename:
            continue
        with codecs.open(os.path.join(data_dir, filename)) as infile:
            text = infile.read()
        docs[filename] = text
        
    print(f'{len(docs)} documents were read from {data_dir}')
    
    return docs

# %% [markdown]
# ## NEL with Babelfy
#
# Demo: http://babelfy.org/
#
# ### Getting an API Key
#
# - It takes only two minues
# - Create an account https://babelnet.org/register
# - Log in and copy your key from https://babelnet.org/home into the cell below...
# - Each key gives you up to 1k API calls per day

# %%
# here goes your Babelfy API key
babelfy_key = "a1ac4b12-4b56-4226-816d-1e682aa6b1c6"

# %% [markdown]
# ### Babelfy API
#
# Use with API:
# - how to get the key
# - where to put it
#
# - Read Quaero test data
# - query API
# - basic display of results

# %% [markdown]
# ### Helpers functions

# %%
import urllib
import json 

# a simple wrapper around Babely's HTTP API
def babelfy_request(text, key, lang='AGNOSTIC', annotation_type='ALL', matching='EXACT_MATCHING'):
    service_url = 'https://babelfy.io/v1/disambiguate'
    matching_strategies = ['PARTIAL_MATCHING', 'EXACT_MATCHING']
    annotation_types = [
        'ALL',
        'NAMED_ENTITIES',
        'CONCEPTS'
    ]
    
    # sanity check on input parameters
    assert annotation_type in annotation_types
    assert matching in matching_strategies

    params = {
    'text' : text,
    'lang' : lang,
    'key'  : key,
    'annType': annotation_type,
    'match': matching
    }

    params = urllib.parse.urlencode(params)
    params = params.encode('utf8') # POST data must be bytes
    req = urllib.request.Request(service_url, data=params, method='POST')
    resp = urllib.request.urlopen(req)
    data = json.loads(resp.read().decode('utf8'))
    print("response successful")
    return data

# %%
def display_babelfy_output(input_doc, b_output):
    """Print Babeblfy's output with minimal formatting."""
    
    print(f"Babelfy found {len(b_output)} links:")
    
    for n, entry in enumerate(b_output):
        start_offset = entry['charFragment']['start']
        end_offset = entry['charFragment']['end'] + 1
        surface = input_doc[start_offset:end_offset]
        entity_link = entry['DBpediaURL'] if entry['DBpediaURL'] else entry['BabelNetURL']
        
        print(f"[{n + 1}] {surface} -> {entity_link}")
    return

# %% [markdown]
# ### Let's test it

# %% [markdown]
# `Babelfy` cannot take as an input a document with **already extracted** mentions.

# %%
# load the impresso dataset
docs = load_impresso_data()
# Out:
# 6 documents were read from ../datasets/impresso/raw/

# %%
# pick one random test document
one_random_doc = np.random.choice(list(docs.keys()))
test_doc = docs[one_random_doc]

# this prints some basic information about the file
print(f'[{one_random_doc}] Contains {len(test_doc.split())} words.\nBegin: {test_doc[:100]}...')
# Out:
# [GDL-1898-08-02-a-i0008.txt] Contains 1997 words.
# Begin: CONFÉDÉRATION SUISSE Simplon. — Un journal du matin annonce que le premier coup de pioche pour le pe...

# %%
# %%time

# call Babelfy's API and store its JSON response
# into a dictionary
babelfy_output = babelfy_request(test_doc, babelfy_key, lang='FR')

# pretty print the entities/concepts + links found by Babelfy
display_babelfy_output(test_doc, babelfy_output)
# Out:
# response successful
# Babelfy found 757 links:
# [1] CONFÉDÉRATION -> http://dbpedia.org/resource/Confederation
# [2] CONFÉDÉRATION SUISSE -> http://dbpedia.org/resource/Switzerland
# [3] SUISSE -> http://dbpedia.org/resource/Switzerland
# [4] journal -> http://dbpedia.org/resource/Newspaper
# [5] matin -> http://dbpedia.org/resource/Morning
# [6] annonce -> http://babelnet.org/rdf/s00082637v
# [7] premier -> http://babelnet.org/rdf/s00103006a
# [8] coup -> http://babelnet.org/rdf/s00011442n
# [9] pioche -> http://dbpedia.org/resource/Pickaxe
# [10] aurait -> http://babelnet.org/rdf/s00088733v
# [11] été -> http://babelnet.org/rdf/s00083187v
# [12] donné -> http://babelnet.org/rdf/s00088815v
# [13] lundi -> http://dbpedia.org/resource/Monday
# [14] lundi matin -> http://babelnet.org/rdf/s03992674n
# [15] matin -> http://dbpedia.org/resource/Morning
# [16] forme -> http://dbpedia.org/resource/Pattern_(architecture)
# [17] information -> http://dbpedia.org/resource/Information
# [18] est -> http://babelnet.org/rdf/s00083187v
# [19] attendu -> http://babelnet.org/rdf/s00089401v
# [20] Conseil -> http://babelnet.org/rdf/s00023134n
# [21] Conseil fédéral -> http://dbpedia.org/resource/Federal_Council_(Switzerland)
# [22] fédéral -> http://babelnet.org/rdf/s00102871a
# [23] pas encore -> http://babelnet.org/rdf/s13692440r
# [24] encore -> http://babelnet.org/rdf/s00114171r
# [25] autorisé -> http://babelnet.org/rdf/s00082538v
# [26] travaux -> http://dbpedia.org/resource/Labour_economics
# [27] pourra -> http://babelnet.org/rdf/s00084451v
# [28] faire -> http://babelnet.org/rdf/s00087107v
# [29] concert -> http://dbpedia.org/resource/Concert
# [30] gouvernement -> http://dbpedia.org/resource/Administration_(government)
# [31] gouvernement italien -> http://dbpedia.org/resource/Politics_of_Italy
# [32] italien -> http://babelnet.org/rdf/s00105493a
# [33] aura -> http://babelnet.org/rdf/s00088733v
# [34] approuvé -> http://babelnet.org/rdf/s00082740v
# [35] justification -> http://dbpedia.org/resource/Theory_of_justification
# [36] financière -> http://babelnet.org/rdf/s00102971a
# [37] compagnie -> http://dbpedia.org/resource/Company_(military_unit)
# [38] formalités -> http://babelnet.org/rdf/s00035936n
# [39] auront -> http://babelnet.org/rdf/s00088733v
# [40] été -> http://babelnet.org/rdf/s00083187v
# [41] Direction -> http://dbpedia.org/resource/Direction_(geometry)
# [42] Jura-Simplon -> http://dbpedia.org/resource/Jura–Simplon_Railway
# [43] notifiera -> http://babelnet.org/rdf/s00082416v
# [44] entreprise -> http://dbpedia.org/resource/Company
# [45] tunnel -> http://dbpedia.org/resource/Tunnel
# [46] invitation -> http://babelnet.org/rdf/s00047375n
# [47] commencer -> http://babelnet.org/rdf/s00083342v
# [48] travaux -> http://dbpedia.org/resource/Labour_economics
# [49] contrat -> http://dbpedia.org/resource/Contract
# [50] forfait -> http://babelnet.org/rdf/s04776255n
# [51] passé -> http://babelnet.org/rdf/s00091458v
# [52] compagnie -> http://dbpedia.org/resource/Company_(military_unit)
# [53] seulement -> http://babelnet.org/rdf/s00116448r
# [54] alors -> http://babelnet.org/rdf/s00117250r
# [55] pourra -> http://babelnet.org/rdf/s00084451v
# [56] être -> http://babelnet.org/rdf/s00083187v
# [57] question -> http://babelnet.org/rdf/s00089845v
# [58] premier -> http://babelnet.org/rdf/s00103006a
# [59] COUD -> http://babelnet.org/rdf/s14382117n
# [60] pioche -> http://dbpedia.org/resource/Pickaxe
# [61] précède -> http://babelnet.org/rdf/s00090247v
# [62] moment -> http://babelnet.org/rdf/s00010728n
# [63] est -> http://babelnet.org/rdf/s00083187v
# [64] préparation -> http://babelnet.org/rdf/s00064167n
# [65] éviter -> http://babelnet.org/rdf/s00082954v
# [66] perte -> http://babelnet.org/rdf/s00052050n
# [67] perte de temps -> http://babelnet.org/rdf/s00080547n
# [68] temps -> http://dbpedia.org/resource/Time
# [69] rentre -> http://babelnet.org/rdf/s00086301v
# [70] catégorie -> http://dbpedia.org/resource/Weight_class_(boxing)
# [71] travaux -> http://dbpedia.org/resource/Labour_economics
# [72] préliminaires -> http://babelnet.org/rdf/s00108949a
# [73] titre -> http://dbpedia.org/resource/Headline
# [74] études -> http://dbpedia.org/resource/Étude
# [75] cas -> http://babelnet.org/rdf/s00016401n
# [76] cas particulier -> http://dbpedia.org/resource/Special_case
# [77] particulier -> http://babelnet.org/rdf/s00108295a
# [78] agit -> http://babelnet.org/rdf/s00082285v
# [79] construction -> http://dbpedia.org/resource/Construction
# [80] route -> http://dbpedia.org/resource/Road
# [81] accès -> http://babelnet.org/rdf/s00000663n
# [82] été -> http://babelnet.org/rdf/s00083187v
# [83] ouvrage -> http://babelnet.org/rdf/s16901954n
# [84] M. -> http://dbpedia.org/resource/Mr.
# [85] Jean -> http://dbpedia.org/resource/John_the_Apostle
# [86] Montreux -> http://dbpedia.org/resource/Montreux
# [87] professeur -> http://dbpedia.org/resource/Professor
# [88] géologie -> http://dbpedia.org/resource/Geology
# [89] académie -> http://dbpedia.org/resource/Academy
# [90] est -> http://babelnet.org/rdf/s00083187v
# [91] nommé -> http://babelnet.org/rdf/s00082716v
# [92] géologue -> http://dbpedia.org/resource/Geologist
# [93] entreprise -> http://dbpedia.org/resource/Company
# [94] Musée -> http://dbpedia.org/resource/Museum
# [95] national -> http://babelnet.org/rdf/s00107137a
# [96] Musée -> http://dbpedia.org/resource/Museum
# [97] reçu -> http://babelnet.org/rdf/s00089246v
# [98] ancienne -> http://babelnet.org/rdf/s00107787a
# [99] famille -> http://dbpedia.org/resource/Family
# [100] don -> http://dbpedia.org/resource/Donation
# [101] important -> http://babelnet.org/rdf/s00104680a
# [102] agit -> http://babelnet.org/rdf/s00082285v
# [103] épée -> http://dbpedia.org/resource/Sword
# [104] médaille -> http://dbpedia.org/resource/Medal
# [105] données -> http://dbpedia.org/resource/Data
# [106] tradition -> http://dbpedia.org/resource/Tradition
# [107] pape -> http://dbpedia.org/resource/Pope
# [108] Sixte -> http://babelnet.org/rdf/s14440312n
# [109] Sixte IV -> http://dbpedia.org/resource/Pope_Sixtus_IV
# [110] bourgmestre -> http://dbpedia.org/resource/Burgomaster
# [111] Zurich -> http://dbpedia.org/resource/Zürich
# [112] grande -> http://babelnet.org/rdf/s00111630a
# [113] valeur -> http://dbpedia.org/resource/Value_(marketing)
# [114] historique -> http://babelnet.org/rdf/s00104223a
# [115] objets -> http://dbpedia.org/resource/Physical_body
# [116] possèdent -> http://babelnet.org/rdf/s00089241v
# [117] valeur -> http://dbpedia.org/resource/Value_(marketing)
# [118] artistique -> http://babelnet.org/rdf/s00097552a
# [119] considérable -> http://babelnet.org/rdf/s00100315a
# [120] surtout -> http://babelnet.org/rdf/s00114082r
# [121] épée -> http://dbpedia.org/resource/Sword
# [122] lame -> http://babelnet.org/rdf/s00049789n
# [123] travail -> http://dbpedia.org/resource/Labour_economics
# [124] oriental -> http://babelnet.org/rdf/s00101967a
# [125] est -> http://babelnet.org/rdf/s00083187v
# [126] poignée -> http://dbpedia.org/resource/Handle_(grip)
# [127] plus -> http://babelnet.org/rdf/s00115880r
# [128] fin -> http://babelnet.org/rdf/s00113911a
# [129] travail -> http://dbpedia.org/resource/Labour_economics
# [130] italien -> http://babelnet.org/rdf/s00105493a
# [131] don -> http://dbpedia.org/resource/Donation
# [132] médaille -> http://dbpedia.org/resource/Medal
# [133] bourgmestre -> http://dbpedia.org/resource/Burgomaster
# [134] historiquement -> http://babelnet.org/rdf/s00115674r
# [135] probable -> http://babelnet.org/rdf/s00105982a
# [136] épée -> http://dbpedia.org/resource/Sword
# [137] pourrait -> http://babelnet.org/rdf/s00084451v
# [138] être -> http://babelnet.org/rdf/s00083187v
# [139] peu -> http://babelnet.org/rdf/s00114044r
# [140] moins -> http://babelnet.org/rdf/s00116104r
# [141] ancienne -> http://babelnet.org/rdf/s00107787a
# [142] avoir -> http://babelnet.org/rdf/s00089240v
# [143] été -> http://babelnet.org/rdf/s00083187v
# [144] capitaine -> http://dbpedia.org/resource/Sea_captain
# [145] tué -> http://babelnet.org/rdf/s00090098v
# [146] lors -> http://babelnet.org/rdf/s00117250r
# [147] prise -> http://babelnet.org/rdf/s00062249n
# [148] prise de Rome -> http://dbpedia.org/resource/Capture_of_Rome
# [149] connétable -> http://babelnet.org/rdf/s15203033n
# [150] Bourbon -> http://dbpedia.org/resource/Bourbon_whiskey
# [151] beau -> http://babelnet.org/rdf/s00098171a
# [152] cadeau -> http://dbpedia.org/resource/Gift
# [153] était -> http://babelnet.org/rdf/s00083187v
# [154] donateurs -> http://babelnet.org/rdf/s00010110n
# [155] preuve -> http://dbpedia.org/resource/Evidence
# [156] monument -> http://dbpedia.org/resource/Memorial
# [157] ancienne -> http://babelnet.org/rdf/s00107787a
# [158] grandeur -> http://babelnet.org/rdf/s00010346n
# [159] famille -> http://dbpedia.org/resource/Family
# [160] montre -> http://dbpedia.org/resource/Watch
# [161] fois -> http://dbpedia.org/resource/Faith
# [162] fois de plus -> http://babelnet.org/rdf/s00114171r
# [163] plus -> http://babelnet.org/rdf/s00115880r
# [164] création -> http://babelnet.org/rdf/s00023652n
# [165] Musée -> http://dbpedia.org/resource/Museum
# [166] national -> http://babelnet.org/rdf/s00107137a
# [167] répondait -> http://babelnet.org/rdf/s00082646v
# [168] besoin -> http://babelnet.org/rdf/s00057164n
# [169] préoccupe -> http://babelnet.org/rdf/s00085522v
# [170] enrichir -> http://babelnet.org/rdf/s00087658v
# [171] Fédération -> http://dbpedia.org/resource/Confederation
# [172] abstinente -> http://babelnet.org/rdf/s13603051a
# [173] La fédération -> http://babelnet.org/rdf/s04844699n
# [174] fédération -> http://dbpedia.org/resource/Confederation
# [175] suisses -> http://babelnet.org/rdf/s00111553a
# [176] abstinence -> http://dbpedia.org/resource/Abstinence
# [177] Olten -> http://dbpedia.org/resource/Olten
# [178] juin -> http://dbpedia.org/resource/June
# [179] juin 1898 -> http://babelnet.org/rdf/s16268044n
# [180] avait -> http://babelnet.org/rdf/s00088733v
# [181] décidé -> http://babelnet.org/rdf/s00086370v
# [182] comité -> http://dbpedia.org/resource/Committee
# [183] comité central -> http://dbpedia.org/resource/Central_Committee
# [184] central -> http://babelnet.org/rdf/s00099441a
# [185] chargé -> http://babelnet.org/rdf/s00090165v
# [186] donner -> http://babelnet.org/rdf/s00088815v
# [187] suite -> http://dbpedia.org/resource/Sequel
# [188] résolutions -> http://babelnet.org/rdf/s00025735n
# [189] assemblée -> http://dbpedia.org/resource/Apella
# [190] été -> http://babelnet.org/rdf/s00083187v
# [191] constitué -> http://babelnet.org/rdf/s00083187v
# [192] Berne -> http://dbpedia.org/resource/Bern
# [193] juillet -> http://dbpedia.org/resource/July
# [194] délégués -> http://dbpedia.org/resource/Delegate
# [195] congrès -> http://dbpedia.org/resource/United_States_Congress
# [196] nommé -> http://babelnet.org/rdf/s00082716v
# [197] bureau -> http://dbpedia.org/resource/Government_agency
# [198] composé -> http://babelnet.org/rdf/s00085489v
# [199] avocat -> http://dbpedia.org/resource/Lawyer
# [200] Bienne -> http://dbpedia.org/resource/Biel/Bienne
# [201] président -> http://dbpedia.org/resource/Chairman
# [202] Jules -> http://babelnet.org/rdf/s13921176n
# [203] Jules Repond -> http://babelnet.org/rdf/s17280520n
# [204] journaliste -> http://babelnet.org/rdf/s00057562n
# [205] Berne -> http://dbpedia.org/resource/Bern
# [206] vice-président -> http://dbpedia.org/resource/Vice_president
# [207] avocat -> http://dbpedia.org/resource/Lawyer
# [208] Langenthal -> http://dbpedia.org/resource/Langenthal
# [209] secrétaire -> http://dbpedia.org/resource/Secretary
# [210] divisé -> http://babelnet.org/rdf/s00084611v
# [211] commissions -> http://dbpedia.org/resource/Commission_(remuneration)
# [212] travail -> http://dbpedia.org/resource/Labour_economics
# [213] étude -> http://dbpedia.org/resource/Étude
# [214] propagande -> http://dbpedia.org/resource/Propaganda
# [215] décidé -> http://babelnet.org/rdf/s00086370v
# [216] convocation -> http://babelnet.org/rdf/s00022328n
# [217] assemblée -> http://dbpedia.org/resource/Apella
# [218] abstinents -> http://babelnet.org/rdf/s13603051a
# [219] obtenir -> http://babelnet.org/rdf/s00091124v
# [220] maintenant -> http://babelnet.org/rdf/s00089384v
# [221] action -> http://babelnet.org/rdf/s00001130n
# [222] ensemble -> http://dbpedia.org/resource/Set_(mathematics)
# [223] sociétés -> http://dbpedia.org/resource/Society
# [224] Patois -> http://dbpedia.org/resource/Patois
# [225] directeurs -> http://dbpedia.org/resource/Schoolmaster
# [226] instruction -> http://dbpedia.org/resource/Statement_(computer_science)
# [227] instruction publique -> http://babelnet.org/rdf/s04690877n
# [228] publique -> http://babelnet.org/rdf/s00109211a
# [229] Suisse -> http://dbpedia.org/resource/Switzerland
# [230] Suisse romande -> http://dbpedia.org/resource/Suisse_romande
# [231] ont -> http://babelnet.org/rdf/s00088733v
# [232] sujet -> http://dbpedia.org/resource/Subject_(philosophy)
# [233] publication -> http://babelnet.org/rdf/s00047693n
# [234] glossaire -> http://dbpedia.org/resource/Glossary
# [235] patois -> http://dbpedia.org/resource/Patois
# [236] suisses -> http://babelnet.org/rdf/s00111553a
# [237] conférences -> http://dbpedia.org/resource/Lecture
# [238] sont -> http://babelnet.org/rdf/s00083187v
# [239] adoption -> http://dbpedia.org/resource/Adoption
# [240] ouvrage -> http://babelnet.org/rdf/s16901954n
# [241] démarches -> http://babelnet.org/rdf/s00026116n
# [242] faites -> http://babelnet.org/rdf/s00087107v
# [243] obtenir -> http://babelnet.org/rdf/s00091124v
# [244] subvention -> http://dbpedia.org/resource/Subsidy
# [245] subvention fédérale -> http://dbpedia.org/resource/Federal_grants_in_the_United_States
# [246] fédérale -> http://babelnet.org/rdf/s00102871a
# [247] suffisante -> http://babelnet.org/rdf/s00100139a
# [248] Sports -> http://dbpedia.org/resource/Athletics_(sport)
# [249] première -> http://babelnet.org/rdf/s00103006a
# [250] automobile -> http://dbpedia.org/resource/Car
# [251] franchi -> http://babelnet.org/rdf/s00086069v
# [252] juillet -> http://dbpedia.org/resource/July
# [253] dernier -> http://babelnet.org/rdf/s00105773a
# [254] correspondant -> http://dbpedia.org/resource/Correspondent
# [255] Suisse -> http://dbpedia.org/resource/Switzerland
# [256] fait -> http://babelnet.org/rdf/s00087107v
# [257] récit -> http://dbpedia.org/resource/Narration
# [258] intéressant -> http://babelnet.org/rdf/s00105276a
# [259] voyage -> http://babelnet.org/rdf/s00048463n
# [260] dit -> http://babelnet.org/rdf/s00093287v
# [261] voiture -> http://dbpedia.org/resource/Passenger_car_(rail)
# [262] personnes -> http://dbpedia.org/resource/Individual
# [263] est -> http://babelnet.org/rdf/s00083187v
# [264] partie -> http://dbpedia.org/resource/Euclidean_vector
# [265] Genève -> http://dbpedia.org/resource/Geneva
# [266] juillet -> http://dbpedia.org/resource/July
# [267] soir -> http://dbpedia.org/resource/Evening
# [268] vitesse -> http://dbpedia.org/resource/Velocity
# [269] vitesse moyenne -> http://dbpedia.org/resource/Speed
# [270] moyenne -> http://babelnet.org/rdf/s00097858a
# [271] kilomètres -> http://dbpedia.org/resource/Kilometre
# [272] heure -> http://dbpedia.org/resource/Hour
# [273] fait -> http://babelnet.org/rdf/s00087107v
# [274] entrée -> http://dbpedia.org/resource/Entryway
# [275] Turin -> http://dbpedia.org/resource/Turin
# [276] juillet -> http://dbpedia.org/resource/July
# [277] matin -> http://dbpedia.org/resource/Morning
# [278] passage -> http://dbpedia.org/resource/Passing_(association_football)
# [279] automobile -> http://babelnet.org/rdf/s00097826a
# [280] excité -> http://babelnet.org/rdf/s00087809v
# [281] grand -> http://babelnet.org/rdf/s00111630a
# [282] étonnement -> http://dbpedia.org/resource/Wonder_(emotion)
# [283] doublait -> http://babelnet.org/rdf/s00087169v
# [284] colère -> http://babelnet.org/rdf/s00004085n
# [285] mystérieuse -> http://babelnet.org/rdf/s00107090a
# [286] machine -> http://dbpedia.org/resource/Machine
# [287] effrayait -> http://babelnet.org/rdf/s00082447v
# [288] animaux -> http://babelnet.org/rdf/s00004234n
# [289] animaux domestiques -> http://babelnet.org/rdf/s00028151n
# [290] domestiques -> http://babelnet.org/rdf/s00101681a
# [291] juillet -> http://dbpedia.org/resource/July
# [292] été -> http://babelnet.org/rdf/s00083187v
# [293] couru -> http://babelnet.org/rdf/s00093170v
# [294] Bellinzone -> http://dbpedia.org/resource/Bellinzona
# [295] Locarno -> http://dbpedia.org/resource/Locarno
# [296] second -> http://babelnet.org/rdf/s00095974a
# [297] championnat -> http://dbpedia.org/resource/Championship
# [298] Sept -> http://dbpedia.org/resource/September
# [299] coureurs -> http://dbpedia.org/resource/Runner_(cricket)
# [300] Lugano -> http://dbpedia.org/resource/Lugano
# [301] est -> http://babelnet.org/rdf/s00083187v
# [302] arrivé -> http://babelnet.org/rdf/s00083286v
# [303] premier -> http://babelnet.org/rdf/s00034738n
# [304] Fava -> http://dbpedia.org/resource/Vicia_faba
# [305] Locarno -> http://dbpedia.org/resource/Locarno
# [306] second -> http://babelnet.org/rdf/s00095974a
# [307] Bellinzone -> http://dbpedia.org/resource/Bellinzona
# [308] troisième -> http://babelnet.org/rdf/s00096000a
# [309] Lugano -> http://dbpedia.org/resource/Lugano
# [310] Biasca -> http://dbpedia.org/resource/Biasca
# [311] Bellinzone -> http://dbpedia.org/resource/Bellinzona
# [312] dernier -> http://babelnet.org/rdf/s00050188n
# [313] dû -> http://babelnet.org/rdf/s00091360v
# [314] changer -> http://babelnet.org/rdf/s00082553v
# [315] fois -> http://dbpedia.org/resource/Faith
# [316] machine -> http://dbpedia.org/resource/Machine
# [317] route -> http://dbpedia.org/resource/Road
# [318] différence -> http://babelnet.org/rdf/s00027022n
# [319] arrivée -> http://babelnet.org/rdf/s00005886n
# [320] but -> http://dbpedia.org/resource/Butane
# [321] était -> http://babelnet.org/rdf/s00083187v
# [322] minutes -> http://dbpedia.org/resource/Minute
# [323] Locarno -> http://dbpedia.org/resource/Locarno
# [324] était -> http://babelnet.org/rdf/s00083187v
# [325] honneur -> http://dbpedia.org/resource/Honour
# [326] fête -> http://dbpedia.org/resource/Calendar_of_saints
# [327] centrale -> http://babelnet.org/rdf/s00099441a
# [328] Union -> http://dbpedia.org/resource/Union_(set_theory)
# [329] Dimanche -> http://dbpedia.org/resource/Lord's_Day
# [330] est -> http://babelnet.org/rdf/s00083187v
# [331] couru -> http://babelnet.org/rdf/s00093170v
# [332] route -> http://dbpedia.org/resource/Road
# [333] retour -> http://babelnet.org/rdf/s00046318n
# [334] championnat -> http://dbpedia.org/resource/Championship
# [335] suisse -> http://babelnet.org/rdf/s00111553a
# [336] route -> http://dbpedia.org/resource/Road
# [337] route 100 -> http://dbpedia.org/resource/New_Brunswick_Route_100
# [338] était -> http://babelnet.org/rdf/s00083187v
# [339] beau -> http://babelnet.org/rdf/s00098171a
# [340] routes -> http://dbpedia.org/resource/Road
# [341] étaient -> http://babelnet.org/rdf/s00092077v
# [342] très -> http://babelnet.org/rdf/s00116789r
# [343] mauvaises -> http://babelnet.org/rdf/s00097966a
# [344] points -> http://babelnet.org/rdf/s00026622n
# [345] coureurs -> http://dbpedia.org/resource/Runner_(cricket)
# [346] sont -> http://babelnet.org/rdf/s00083187v
# [347] départ -> http://babelnet.org/rdf/s00026343n
# [348] Voici -> http://dbpedia.org/resource/Voici
# [349] premiers -> http://babelnet.org/rdf/s00103006a
# [350] arrivants -> http://babelnet.org/rdf/s00031049n
# [351] Zurich -> http://dbpedia.org/resource/Zürich
# [352] Em -> http://dbpedia.org/resource/Pica_(typography)
# [353] Barrot -> http://babelnet.org/rdf/s15429725n
# [354] Genève -> http://dbpedia.org/resource/Geneva
# [355] Berne -> http://dbpedia.org/resource/Bern
# [356] Ch -> http://dbpedia.org/resource/Horsepower
# [357] Calame -> http://dbpedia.org/resource/Reed_pen
# [358] Genève -> http://dbpedia.org/resource/Geneva
# [359] Bienne -> http://dbpedia.org/resource/Biel/Bienne
# [360] courge -> http://babelnet.org/rdf/s00086115v
# [361] groupes -> http://babelnet.org/rdf/s00041942n
# [362] société -> http://dbpedia.org/resource/Society
# [363] prenant -> http://babelnet.org/rdf/s00088762v
# [364] part -> http://babelnet.org/rdf/s00060766n
# [365] course -> http://dbpedia.org/resource/Racing
# [366] avait -> http://babelnet.org/rdf/s00088733v
# [367] désigner -> http://babelnet.org/rdf/s00086585v
# [368] coureurs -> http://dbpedia.org/resource/Runner_(cricket)
# [369] Vélo -> http://dbpedia.org/resource/Bicycle
# [370] Vélo Club -> http://babelnet.org/rdf/s17061372n
# [371] Club -> http://babelnet.org/rdf/s00008141n
# [372] Sihl -> http://dbpedia.org/resource/Sihl
# [373] Zurich -> http://dbpedia.org/resource/Zürich
# [374] est -> http://babelnet.org/rdf/s00083187v
# [375] arrivé -> http://babelnet.org/rdf/s00083286v
# [376] premier -> http://babelnet.org/rdf/s00034738n
# [377] ayant -> http://babelnet.org/rdf/s00088733v
# [378] heure -> http://dbpedia.org/resource/Hour
# [379] minutes -> http://dbpedia.org/resource/Minute
# [380] secondes -> http://dbpedia.org/resource/Second
# [381] franchir -> http://babelnet.org/rdf/s00086069v
# [382] kil -> http://dbpedia.org/resource/Kilo-
# [383] ensuite -> http://babelnet.org/rdf/s00116086r
# [384] Genève -> http://dbpedia.org/resource/Geneva
# [385] Berne -> http://dbpedia.org/resource/Bern
# [386] Bienne -> http://dbpedia.org/resource/Biel/Bienne
# [387] St-Imier -> http://dbpedia.org/resource/Saint-Imier
# [388] etc -> http://babelnet.org/rdf/s00114282r
# [389] gens -> http://dbpedia.org/resource/Gens
# [390] mal -> http://babelnet.org/rdf/s00114486r
# [391] intentionnés -> http://babelnet.org/rdf/s00113788a
# [392] avaient -> http://babelnet.org/rdf/s00088733v
# [393] semé -> http://babelnet.org/rdf/s00093447v
# [394] route -> http://dbpedia.org/resource/Road
# [395] petits -> http://babelnet.org/rdf/s00106062a
# [396] tapissiers -> http://babelnet.org/rdf/s00079247n
# [397] Beaucoup -> http://dbpedia.org/resource/Slew_(spacecraft)
# [398] machines -> http://dbpedia.org/resource/Machine
# [399] ont -> http://babelnet.org/rdf/s00088733v
# [400] été -> http://babelnet.org/rdf/s00083187v
# [401] coureurs -> http://dbpedia.org/resource/Runner_(cricket)
# [402] sont -> http://babelnet.org/rdf/s00083187v
# [403] Concurrence -> http://dbpedia.org/resource/Competition_(economics)
# [404] italienne -> http://babelnet.org/rdf/s00105493a
# [405] députation -> http://dbpedia.org/resource/Delegation
# [406] Assemblée -> http://dbpedia.org/resource/Apella
# [407] Assemblée fédérale -> http://dbpedia.org/resource/Federal_Assembly_(Switzerland)
# [408] fédérale -> http://babelnet.org/rdf/s00102871a
# [409] vient -> http://babelnet.org/rdf/s00085322v
# [410] être -> http://babelnet.org/rdf/s00083187v
# [411] aurait -> http://babelnet.org/rdf/s00088733v
# [412] appuyé -> http://babelnet.org/rdf/s00083243v
# [413] pétition -> http://dbpedia.org/resource/Petition
# [414] ouvriers -> http://dbpedia.org/resource/Laborer
# [415] résidant -> http://babelnet.org/rdf/s00087617v
# [416] Berne -> http://dbpedia.org/resource/Bern
# [417] pétition -> http://dbpedia.org/resource/Petition
# [418] emploi -> http://dbpedia.org/resource/Employment
# [419] ouvriers -> http://dbpedia.org/resource/Laborer
# [420] italiens -> http://babelnet.org/rdf/s00105493a
# [421] construction -> http://dbpedia.org/resource/Construction
# [422] palais -> http://dbpedia.org/resource/Palate
# [423] parlement -> http://dbpedia.org/resource/Parliament
# [424] prend -> http://babelnet.org/rdf/s00088762v
# [425] défense -> http://babelnet.org/rdf/s00025878n
# [426] députés -> http://babelnet.org/rdf/s00026425n
# [427] ont -> http://babelnet.org/rdf/s00088733v
# [428] fait -> http://babelnet.org/rdf/s00087107v
# [429] démarches -> http://babelnet.org/rdf/s00026116n
# [430] circonstances -> http://dbpedia.org/resource/Consideration
# [431] reste -> http://babelnet.org/rdf/s00085719v
# [432] concurrence -> http://dbpedia.org/resource/Competition_(economics)
# [433] italienne -> http://babelnet.org/rdf/s00105493a
# [434] plaignent -> http://babelnet.org/rdf/s00085471v
# [435] est -> http://babelnet.org/rdf/s00083187v
# [436] modestes -> http://babelnet.org/rdf/s00106839a
# [437] limites -> http://babelnet.org/rdf/s00012419n
# [438] ouvriers -> http://dbpedia.org/resource/Laborer
# [439] seulement -> http://babelnet.org/rdf/s00116448r
# [440] sont -> http://babelnet.org/rdf/s00083187v
# [441] origine -> http://babelnet.org/rdf/s00009635n
# [442] italienne -> http://babelnet.org/rdf/s00105493a
# [443] conférence -> http://dbpedia.org/resource/Lecture
# [444] M. -> http://dbpedia.org/resource/Mr.
# [445] conseiller -> http://babelnet.org/rdf/s00082415v
# [446] national -> http://babelnet.org/rdf/s00107137a
# [447] fait -> http://babelnet.org/rdf/s00087107v
# [448] partie -> http://dbpedia.org/resource/Euclidean_vector
# [449] syndicat -> http://dbpedia.org/resource/Trade_union
# [450] département -> http://dbpedia.org/resource/Departments_of_France
# [451] fédéral -> http://babelnet.org/rdf/s00102871a
# [452] Intérieur -> http://babelnet.org/rdf/s00046891n
# [453] ailleurs -> http://babelnet.org/rdf/s00115192r
# [454] invité -> http://babelnet.org/rdf/s00089890v
# [455] ledit -> http://babelnet.org/rdf/s00096622a
# [456] syndicat -> http://dbpedia.org/resource/Trade_union
# [457] donner -> http://babelnet.org/rdf/s00088815v
# [458] autant -> http://babelnet.org/rdf/s00116285r
# [459] autant que possible -> http://babelnet.org/rdf/s00114358r
# [460] possible -> http://babelnet.org/rdf/s00108829a
# [461] préférence -> http://dbpedia.org/resource/Preference
# [462] ouvriers -> http://dbpedia.org/resource/Laborer
# [463] indigènes -> http://babelnet.org/rdf/s00096168a
# [464] réponse -> http://babelnet.org/rdf/s00004451n
# [465] entrepreneurs -> http://babelnet.org/rdf/s00031011n
# [466] manqueront -> http://babelnet.org/rdf/s00090161v
# [467] engager -> http://babelnet.org/rdf/s00083132v
# [468] bons -> http://babelnet.org/rdf/s00103672a
# [469] maçons -> http://dbpedia.org/resource/Bricklayer
# [470] ouvriers -> http://dbpedia.org/resource/Laborer
# [471] occasion -> http://babelnet.org/rdf/s00017621n
# [472] présentera -> http://babelnet.org/rdf/s00090234v
# [473] est -> http://babelnet.org/rdf/s00083187v
# [474] fraternité -> http://dbpedia.org/resource/Fraternity
# [475] socialiste -> http://babelnet.org/rdf/s00110849a
# [476] propos -> http://dbpedia.org/resource/Marriage_proposal
# [477] exode -> http://babelnet.org/rdf/s00032250n
# [478] ouvriers -> http://dbpedia.org/resource/Laborer
# [479] italiens -> http://babelnet.org/rdf/s00105493a
# [480] incident -> http://babelnet.org/rdf/s00104815a
# [481] Chiasso -> http://dbpedia.org/resource/Chiasso
# [482] Sanatorium -> http://dbpedia.org/resource/Sanatorium
# [483] buveurs -> http://babelnet.org/rdf/s00028752n
# [484] juillet -> http://dbpedia.org/resource/July
# [485] été -> http://babelnet.org/rdf/s00083187v
# [486] ouvert -> http://babelnet.org/rdf/s00091165v
# [487] Ermatingen -> http://dbpedia.org/resource/Ermatingen
# [488] lac -> http://dbpedia.org/resource/Lake
# [489] lac de Constance -> http://dbpedia.org/resource/Lake_Constance
# [490] sanatorium -> http://dbpedia.org/resource/Sanatorium
# [491] nouveau -> http://babelnet.org/rdf/s00107267a
# [492] genre -> http://babelnet.org/rdf/s00035907n
# [493] personnes -> http://dbpedia.org/resource/Individual
# [494] malades -> http://babelnet.org/rdf/s00096705a
# [495] suites -> http://dbpedia.org/resource/Sequel
# [496] abus -> http://dbpedia.org/resource/Abuse
# [497] alcool -> http://dbpedia.org/resource/Alcoholic_beverage
# [498] autres -> http://babelnet.org/rdf/s00101268a
# [499] intoxications -> http://babelnet.org/rdf/s00047259n
# [500] narcotiques -> http://babelnet.org/rdf/s00107114a
# [501] buveurs -> http://babelnet.org/rdf/s00028752n
# [502] classes -> http://dbpedia.org/resource/Music_examination
# [503] aisées -> http://babelnet.org/rdf/s00100071a
# [504] établissement -> http://babelnet.org/rdf/s00029598n
# [505] est -> http://babelnet.org/rdf/s00083187v
# [506] installé -> http://babelnet.org/rdf/s00089786v
# [507] magnifique -> http://babelnet.org/rdf/s00096926a
# [508] propriété -> http://dbpedia.org/resource/Property_(philosophy)
# [509] château -> http://dbpedia.org/resource/Castle
# [510] offre -> http://babelnet.org/rdf/s00091136v
# [511] pensionnaires -> http://dbpedia.org/resource/Pensionary
# [512] confort -> http://babelnet.org/rdf/s00020913n
# [513] possible -> http://babelnet.org/rdf/s00108829a
# [514] trouve -> http://babelnet.org/rdf/s00084231v
# [515] parc -> http://dbpedia.org/resource/Park
# [516] splendide -> http://babelnet.org/rdf/s00110549a
# [517] serres -> http://dbpedia.org/resource/Nursery_(room)
# [518] jardins -> http://dbpedia.org/resource/Garden
# [519] hiver -> http://dbpedia.org/resource/Winter
# [520] chasser -> http://babelnet.org/rdf/s00084834v
# [521] pêcher -> http://babelnet.org/rdf/s00088236v
# [522] faire -> http://babelnet.org/rdf/s00087107v
# [523] canotage -> http://dbpedia.org/resource/Whitewater_canoeing
# [524] établissement -> http://babelnet.org/rdf/s00029598n
# [525] été -> http://babelnet.org/rdf/s00083187v
# [526] fondé -> http://babelnet.org/rdf/s00083141v
# [527] but -> http://dbpedia.org/resource/Butane
# [528] purement -> http://babelnet.org/rdf/s00116774r
# [529] philanthropique -> http://babelnet.org/rdf/s00108525a
# [530] société -> http://dbpedia.org/resource/Society
# [531] anonyme -> http://babelnet.org/rdf/s00097155a
# [532] distribuera -> http://babelnet.org/rdf/s00082364v
# [533] actionnaires -> http://dbpedia.org/resource/Shareholder
# [534] intérêt -> http://dbpedia.org/resource/Interest
# [535] modeste -> http://babelnet.org/rdf/s00106839a
# [536] limité -> http://babelnet.org/rdf/s00105999a
# [537] consacrera -> http://babelnet.org/rdf/s00085427v
# [538] bénéfices -> http://dbpedia.org/resource/Profit_(economics)
# [539] lutte -> http://babelnet.org/rdf/s00009079n
# [540] alcoolisme -> http://dbpedia.org/resource/Alcoholism
# [541] ainsi -> http://babelnet.org/rdf/s00117048r
# [542] amélioration -> http://dbpedia.org/resource/Betterment
# [543] agrandissement -> http://babelnet.org/rdf/s00052754n
# [544] entreprise -> http://dbpedia.org/resource/Company
# [545] initiative -> http://dbpedia.org/resource/Initiative_(enterprise)
# [546] patronage -> http://babelnet.org/rdf/s15752158n
# [547] œuvre -> http://dbpedia.org/resource/Oeuvre
# [548] appartiennent -> http://babelnet.org/rdf/s00083391v
# [549] groupe -> http://babelnet.org/rdf/s00041942n
# [550] suisses -> http://babelnet.org/rdf/s00111553a
# [551] composé -> http://babelnet.org/rdf/s00085489v
# [552] Munsterlingen -> http://dbpedia.org/resource/Münsterlingen
# [553] professeur -> http://dbpedia.org/resource/Professor
# [554] Zurich -> http://dbpedia.org/resource/Zürich
# [555] professeur -> http://dbpedia.org/resource/Professor
# [556] Berne -> http://dbpedia.org/resource/Bern
# [557] Forel -> http://dbpedia.org/resource/Forel,_Vaud
# [558] professeur -> http://dbpedia.org/resource/Professor
# [559] maison -> http://dbpedia.org/resource/House
# [560] été -> http://babelnet.org/rdf/s00083187v
# [561] médecin -> http://dbpedia.org/resource/Physician
# [562] distingué -> http://babelnet.org/rdf/s00086799v
# [563] est -> http://babelnet.org/rdf/s00083187v
# [564] naturellement -> http://babelnet.org/rdf/s00114869r
# [565] abstinent -> http://dbpedia.org/resource/Teetotalism
# [566] convaincu -> http://babelnet.org/rdf/s00100431a
# [567] grande -> http://babelnet.org/rdf/s00111630a
# [568] pratique -> http://dbpedia.org/resource/Practice_(learning_method)
# [569] thérapeutique -> http://babelnet.org/rdf/s00111810a
# [570] sug -> http://dbpedia.org/resource/Sug
# [571] Société -> http://dbpedia.org/resource/Society
# [572] Société helvétique des sciences naturelles -> http://dbpedia.org/resource/Swiss_Academy_of_Natural_Sciences
# [573] sciences -> http://dbpedia.org/resource/Science
# [574] sciences naturelles -> http://dbpedia.org/resource/Natural_science
# [575] naturelles -> http://babelnet.org/rdf/s00107151a
# [576] société -> http://dbpedia.org/resource/Society
# [577] été -> http://babelnet.org/rdf/s00083187v
# [578] Genève -> http://dbpedia.org/resource/Geneva
# [579] adhérents -> http://dbpedia.org/resource/Disciple_(Christianity)
# [580] Lausannois -> http://dbpedia.org/resource/Lausanne
# [581] organisation -> http://dbpedia.org/resource/Organization
# [582] date -> http://babelnet.org/rdf/s00086297v
# [583] année -> http://dbpedia.org/resource/Tropical_year
# [584] suivante -> http://babelnet.org/rdf/s00103172a
# [585] époque -> http://dbpedia.org/resource/Epoch_(reference_date)
# [586] existait -> http://babelnet.org/rdf/s00083184v
# [587] Suisse -> http://dbpedia.org/resource/Switzerland
# [588] sociétés -> http://dbpedia.org/resource/Society
# [589] histoire -> http://dbpedia.org/resource/History
# [590] histoire naturelle -> http://dbpedia.org/resource/Natural_history
# [591] naturelle -> http://babelnet.org/rdf/s00107151a
# [592] Zurich -> http://dbpedia.org/resource/Zürich
# [593] Berne -> http://dbpedia.org/resource/Bern
# [594] datant -> http://babelnet.org/rdf/s00086297v
# [595] Société -> http://dbpedia.org/resource/Society
# [596] physique -> http://dbpedia.org/resource/Physics
# [597] histoire -> http://dbpedia.org/resource/History
# [598] histoire naturelle -> http://dbpedia.org/resource/Natural_history
# [599] naturelle -> http://babelnet.org/rdf/s00107151a
# [600] Genève -> http://dbpedia.org/resource/Geneva
# [601] enfin -> http://babelnet.org/rdf/s00114417r
# [602] Société -> http://dbpedia.org/resource/Society
# [603] Actuellement -> http://babelnet.org/rdf/s00077463n
# [604] Société -> http://dbpedia.org/resource/Society
# [605] Société helvétique des sciences naturelles -> http://dbpedia.org/resource/Swiss_Academy_of_Natural_Sciences
# [606] sciences -> http://dbpedia.org/resource/Science
# [607] sciences naturelles -> http://dbpedia.org/resource/Natural_science
# [608] naturelles -> http://babelnet.org/rdf/s00107151a
# [609] compte -> http://babelnet.org/rdf/s00085859v
# [610] membres -> http://babelnet.org/rdf/s00034004n
# [611] résidant -> http://babelnet.org/rdf/s00087617v
# [612] Suisse -> http://dbpedia.org/resource/Switzerland
# [613] étranger -> http://babelnet.org/rdf/s00002726n
# [614] membres -> http://babelnet.org/rdf/s00034004n
# [615] honneur -> http://dbpedia.org/resource/Honour
# [616] sections -> http://dbpedia.org/resource/Section_(botany)
# [617] plus -> http://babelnet.org/rdf/s00115880r
# [618] nombreuses -> http://babelnet.org/rdf/s00107028a
# [619] sont -> http://babelnet.org/rdf/s00083187v
# [620] Genève -> http://dbpedia.org/resource/Geneva
# [621] membres -> http://babelnet.org/rdf/s00034004n
# [622] Zurich -> http://dbpedia.org/resource/Zürich
# [623] Vaud -> http://dbpedia.org/resource/Vaud
# [624] assemblée -> http://dbpedia.org/resource/Apella
# [625] générale -> http://babelnet.org/rdf/s00103507a
# [626] août -> http://dbpedia.org/resource/August
# [627] Berne -> http://dbpedia.org/resource/Bern
# [628] Société -> http://dbpedia.org/resource/Society
# [629] Société helvétique des sciences naturelles -> http://dbpedia.org/resource/Swiss_Academy_of_Natural_Sciences
# [630] sciences -> http://dbpedia.org/resource/Science
# [631] sciences naturelles -> http://dbpedia.org/resource/Natural_science
# [632] naturelles -> http://babelnet.org/rdf/s00107151a
# [633] procédé -> http://dbpedia.org/resource/Process_(engineering)
# [634] réception -> http://babelnet.org/rdf/s00066489n
# [635] quarante-six -> http://dbpedia.org/resource/46_(number)
# [636] nouveaux -> http://babelnet.org/rdf/s00107267a
# [637] membres -> http://babelnet.org/rdf/s00034004n
# [638] désignation -> http://dbpedia.org/resource/Appellation
# [639] membres -> http://babelnet.org/rdf/s00034004n
# [640] honoraires -> http://dbpedia.org/resource/Honorarium
# [641] étrangers -> http://babelnet.org/rdf/s00103205a
# [642] nouveau -> http://babelnet.org/rdf/s00107267a
# [643] comité -> http://dbpedia.org/resource/Committee
# [644] comité central -> http://dbpedia.org/resource/Central_Committee
# [645] central -> http://babelnet.org/rdf/s00099441a
# [646] été -> http://babelnet.org/rdf/s00083187v
# [647] transféré -> http://babelnet.org/rdf/s00084790v
# [648] Zurich -> http://dbpedia.org/resource/Zürich
# [649] professeur -> http://dbpedia.org/resource/Professor
# [650] été -> http://babelnet.org/rdf/s00083187v
# [651] nommé -> http://babelnet.org/rdf/s00082716v
# [652] président -> http://dbpedia.org/resource/Chairman
# [653] prochaine -> http://babelnet.org/rdf/s00097396a
# [654] assemblée -> http://dbpedia.org/resource/Apella
# [655] BOUS -> http://dbpedia.org/resource/Bous,_Germany
# [656] présidence -> http://babelnet.org/rdf/s00017524n
# [657] professeur -> http://dbpedia.org/resource/Professor
# [658] assemblée -> http://dbpedia.org/resource/Apella
# [659] voté -> http://babelnet.org/rdf/s00095572v
# [660] outre -> http://babelnet.org/rdf/s00114534r
# [661] crédits -> http://babelnet.org/rdf/s00023667n
# [662] commissions -> http://dbpedia.org/resource/Commission_(remuneration)
# [663] renvoyé -> http://babelnet.org/rdf/s00088506v
# [664] comité -> http://dbpedia.org/resource/Committee
# [665] proposition -> http://babelnet.org/rdf/s00064779n
# [666] professeur -> http://dbpedia.org/resource/Professor
# [667] Graf -> http://dbpedia.org/resource/Stephanie_Graf
# [668] Berne -> http://dbpedia.org/resource/Bern
# [669] sujet -> http://dbpedia.org/resource/Subject_(philosophy)
# [670] publication -> http://babelnet.org/rdf/s00047693n
# [671] savants -> http://dbpedia.org/resource/Pundit
# [672] célèbres -> http://babelnet.org/rdf/s00099411a
# [673] été -> http://babelnet.org/rdf/s00083187v
# [674] lecture -> http://dbpedia.org/resource/Reading_(process)
# [675] rapports -> http://dbpedia.org/resource/Report
# [676] scientifiques -> http://babelnet.org/rdf/s00110175a
# [677] professeur -> http://dbpedia.org/resource/Professor
# [678] Studer -> http://dbpedia.org/resource/Studer_(surname)
# [679] Berne -> http://dbpedia.org/resource/Bern
# [680] Strasbourg -> http://dbpedia.org/resource/Strasbourg
# [681] professeur -> http://dbpedia.org/resource/Professor
# [682] Zurich -> http://dbpedia.org/resource/Zürich
# [683] professeur -> http://dbpedia.org/resource/Professor
# [684] Genève -> http://dbpedia.org/resource/Geneva
# [685] banquet -> http://dbpedia.org/resource/Banquet
# [686] eu -> http://babelnet.org/rdf/s00088733v
# [687] lien -> http://dbpedia.org/resource/Hyperlink
# [688] galle -> http://dbpedia.org/resource/Gall
# [689] Musée -> http://dbpedia.org/resource/Museum
# [690] comptait -> http://babelnet.org/rdf/s00085859v
# [691] orchestre -> http://dbpedia.org/resource/Orchestra
# [692] Ville -> http://dbpedia.org/resource/Town
# [693] sont -> http://babelnet.org/rdf/s00083187v
# [694] fait -> http://babelnet.org/rdf/s00087107v
# [695] entendre -> http://babelnet.org/rdf/s00089277v
# [696] discours -> http://babelnet.org/rdf/s00049018n
# [697] ont -> http://babelnet.org/rdf/s00088733v
# [698] été -> http://babelnet.org/rdf/s00083187v
# [699] M. -> http://dbpedia.org/resource/Mr.
# [700] Studer -> http://dbpedia.org/resource/Studer_(surname)
# [701] porté -> http://babelnet.org/rdf/s00089252v
# [702] toast -> http://dbpedia.org/resource/Toast_(honor)
# [703] patrie -> http://dbpedia.org/resource/Homeland
# [704] conseiller -> http://dbpedia.org/resource/Consultant
# [705] Etat -> http://babelnet.org/rdf/s00074010n
# [706] Lindt -> http://babelnet.org/rdf/s13859064n
# [707] président -> http://dbpedia.org/resource/Chairman
# [708] ville -> http://dbpedia.org/resource/Town
# [709] ont -> http://babelnet.org/rdf/s00088733v
# [710] souhaité -> http://babelnet.org/rdf/s00095805v
# [711] bienvenue -> http://babelnet.org/rdf/s00080852n
# [712] membres -> http://babelnet.org/rdf/s00034004n
# [713] membres du congrès -> http://dbpedia.org/resource/Member_of_Congress
# [714] congrès -> http://dbpedia.org/resource/United_States_Congress
# [715] nom -> http://dbpedia.org/resource/Name
# [716] autorités -> http://dbpedia.org/resource/Authorization
# [717] municipales -> http://babelnet.org/rdf/s15765465n
# [718] M. -> http://dbpedia.org/resource/Mr.
# [719] le professeur -> http://dbpedia.org/resource/La_prima_notte_di_quiete
# [720] professeur -> http://dbpedia.org/resource/Professor
# [721] Forel -> http://dbpedia.org/resource/Forel,_Vaud
# [722] répondu -> http://babelnet.org/rdf/s00082646v
# [723] été -> http://babelnet.org/rdf/s00083187v
# [724] donné -> http://babelnet.org/rdf/s00088815v
# [725] lecture -> http://dbpedia.org/resource/Reading_(process)
# [726] grand -> http://babelnet.org/rdf/s00111630a
# [727] grand nombre -> http://dbpedia.org/resource/Large_numbers
# [728] nombre -> http://dbpedia.org/resource/Number
# [729] télégrammes -> http://babelnet.org/rdf/s00076382n
# [730] banquet -> http://dbpedia.org/resource/Banquet
# [731] société -> http://dbpedia.org/resource/Society
# [732] est -> http://babelnet.org/rdf/s00083187v
# [733] partie -> http://dbpedia.org/resource/Euclidean_vector
# [734] forêt -> http://dbpedia.org/resource/Wood_(golf)
# [735] Bremgarten -> http://dbpedia.org/resource/Bremgarten,_Aargau
# [736] devait -> http://babelnet.org/rdf/s00091360v
# [737] assister -> http://babelnet.org/rdf/s00082907v
# [738] représentation -> http://dbpedia.org/resource/Mental_representation
# [739] pièce -> http://dbpedia.org/resource/Coin
# [740] humoristique -> http://babelnet.org/rdf/s00097006a
# [741] programme -> http://dbpedia.org/resource/Curriculum
# [742] mercredi -> http://dbpedia.org/resource/Wednesday
# [743] août -> http://dbpedia.org/resource/August
# [744] prévoit -> http://babelnet.org/rdf/s00082665v
# [745] excursion -> http://dbpedia.org/resource/Excursion
# [746] Grindelwald -> http://dbpedia.org/resource/Grindelwald
# [747] départ -> http://babelnet.org/rdf/s00026343n
# [748] Berne -> http://dbpedia.org/resource/Bern
# [749] train -> http://dbpedia.org/resource/Train
# [750] spécial -> http://babelnet.org/rdf/s00102635a
# [751] matin -> http://dbpedia.org/resource/Morning
# [752] arrivée -> http://babelnet.org/rdf/s00005886n
# [753] destination -> http://babelnet.org/rdf/s00026601n
# [754] séance -> http://dbpedia.org/resource/Séance
# [755] aura -> http://babelnet.org/rdf/s00088733v
# [756] lieu -> http://dbpedia.org/resource/Archaeological_context
# [757] midi -> http://dbpedia.org/resource/Noon
# CPU times: user 67 ms, sys: 20.8 ms, total: 87.8 ms
# Wall time: 4.78 s

# %%
babelfy_output = babelfy_request(
    test_doc,
    babelfy_key,
    lang='FR',
    annotation_type='NAMED_ENTITIES'
)
display_babelfy_output(test_doc, babelfy_output)
# Out:
# response successful
# Babelfy found 84 links:
# [1] CONFÉDÉRATION SUISSE -> http://dbpedia.org/resource/Switzerland
# [2] SUISSE -> http://dbpedia.org/resource/Switzerland
# [3] Conseil fédéral -> http://dbpedia.org/resource/Federal_Council_(Switzerland)
# [4] gouvernement italien -> http://dbpedia.org/resource/Politics_of_Italy
# [5] Jura-Simplon -> http://dbpedia.org/resource/Jura–Simplon_Railway
# [6] Jean -> http://dbpedia.org/resource/John_the_Apostle
# [7] Montreux -> http://dbpedia.org/resource/Montreux
# [8] Sixte IV -> http://dbpedia.org/resource/Pope_Sixtus_IV
# [9] Zurich -> http://dbpedia.org/resource/Zürich
# [10] prise de Rome -> http://dbpedia.org/resource/Capture_of_Rome
# [11] La fédération -> http://babelnet.org/rdf/s04844699n
# [12] Olten -> http://dbpedia.org/resource/Olten
# [13] juin 1898 -> http://babelnet.org/rdf/s16268044n
# [14] comité central -> http://dbpedia.org/resource/Central_Committee
# [15] Berne -> http://dbpedia.org/resource/Bern
# [16] Bienne -> http://dbpedia.org/resource/Biel/Bienne
# [17] Jules Repond -> http://babelnet.org/rdf/s17280520n
# [18] Berne -> http://dbpedia.org/resource/Bern
# [19] Langenthal -> http://dbpedia.org/resource/Langenthal
# [20] Suisse -> http://dbpedia.org/resource/Switzerland
# [21] Suisse -> http://dbpedia.org/resource/Switzerland
# [22] Genève -> http://dbpedia.org/resource/Geneva
# [23] Turin -> http://dbpedia.org/resource/Turin
# [24] Bellinzone -> http://dbpedia.org/resource/Bellinzona
# [25] Locarno -> http://dbpedia.org/resource/Locarno
# [26] Lugano -> http://dbpedia.org/resource/Lugano
# [27] Locarno -> http://dbpedia.org/resource/Locarno
# [28] Bellinzone -> http://dbpedia.org/resource/Bellinzona
# [29] Lugano -> http://dbpedia.org/resource/Lugano
# [30] Biasca -> http://dbpedia.org/resource/Biasca
# [31] Bellinzone -> http://dbpedia.org/resource/Bellinzona
# [32] Locarno -> http://dbpedia.org/resource/Locarno
# [33] route 100 -> http://dbpedia.org/resource/New_Brunswick_Route_100
# [34] Zurich -> http://dbpedia.org/resource/Zürich
# [35] Genève -> http://dbpedia.org/resource/Geneva
# [36] Berne -> http://dbpedia.org/resource/Bern
# [37] Genève -> http://dbpedia.org/resource/Geneva
# [38] Bienne -> http://dbpedia.org/resource/Biel/Bienne
# [39] Vélo Club -> http://babelnet.org/rdf/s17061372n
# [40] Sihl -> http://dbpedia.org/resource/Sihl
# [41] Zurich -> http://dbpedia.org/resource/Zürich
# [42] Genève -> http://dbpedia.org/resource/Geneva
# [43] Berne -> http://dbpedia.org/resource/Bern
# [44] Bienne -> http://dbpedia.org/resource/Biel/Bienne
# [45] St-Imier -> http://dbpedia.org/resource/Saint-Imier
# [46] Assemblée fédérale -> http://dbpedia.org/resource/Federal_Assembly_(Switzerland)
# [47] Berne -> http://dbpedia.org/resource/Bern
# [48] Chiasso -> http://dbpedia.org/resource/Chiasso
# [49] Ermatingen -> http://dbpedia.org/resource/Ermatingen
# [50] lac de Constance -> http://dbpedia.org/resource/Lake_Constance
# [51] Munsterlingen -> http://dbpedia.org/resource/Münsterlingen
# [52] Zurich -> http://dbpedia.org/resource/Zürich
# [53] Berne -> http://dbpedia.org/resource/Bern
# [54] Forel -> http://dbpedia.org/resource/Forel,_Vaud
# [55] sug -> http://dbpedia.org/resource/Sug
# [56] Société helvétique des sciences naturelles -> http://dbpedia.org/resource/Swiss_Academy_of_Natural_Sciences
# [57] Genève -> http://dbpedia.org/resource/Geneva
# [58] Lausannois -> http://dbpedia.org/resource/Lausanne
# [59] Suisse -> http://dbpedia.org/resource/Switzerland
# [60] Zurich -> http://dbpedia.org/resource/Zürich
# [61] Berne -> http://dbpedia.org/resource/Bern
# [62] Genève -> http://dbpedia.org/resource/Geneva
# [63] Société helvétique des sciences naturelles -> http://dbpedia.org/resource/Swiss_Academy_of_Natural_Sciences
# [64] Suisse -> http://dbpedia.org/resource/Switzerland
# [65] Genève -> http://dbpedia.org/resource/Geneva
# [66] Zurich -> http://dbpedia.org/resource/Zürich
# [67] Vaud -> http://dbpedia.org/resource/Vaud
# [68] Berne -> http://dbpedia.org/resource/Bern
# [69] Société helvétique des sciences naturelles -> http://dbpedia.org/resource/Swiss_Academy_of_Natural_Sciences
# [70] comité central -> http://dbpedia.org/resource/Central_Committee
# [71] Zurich -> http://dbpedia.org/resource/Zürich
# [72] BOUS -> http://dbpedia.org/resource/Bous,_Germany
# [73] Graf -> http://dbpedia.org/resource/Stephanie_Graf
# [74] Berne -> http://dbpedia.org/resource/Bern
# [75] Studer -> http://dbpedia.org/resource/Studer_(surname)
# [76] Berne -> http://dbpedia.org/resource/Bern
# [77] Strasbourg -> http://dbpedia.org/resource/Strasbourg
# [78] Zurich -> http://dbpedia.org/resource/Zürich
# [79] Genève -> http://dbpedia.org/resource/Geneva
# [80] Studer -> http://dbpedia.org/resource/Studer_(surname)
# [81] Forel -> http://dbpedia.org/resource/Forel,_Vaud
# [82] Bremgarten -> http://dbpedia.org/resource/Bremgarten,_Aargau
# [83] Grindelwald -> http://dbpedia.org/resource/Grindelwald
# [84] Berne -> http://dbpedia.org/resource/Bern

# %% [markdown]
# ### tweak parameters. run. compare. repeat.
#
# Changing the API's settings does change the output you will get.
#
# Parameters you can fiddle with:
# - `annotation_type`
# - `lang`
# - `matching` (try to `PARTIAL_MATCHING` and time it with `%%time`)

# %% [markdown]
# ### Test robustness
#
# Try to insert OCR errors before calling `Babelfy`.

# %% [markdown]
# ## NEL with Aida
#
# System demo: [Aida Web](https://gate.d5.mpi-inf.mpg.de/webaida/)
#
# Reference publication: [Hoffart et al. *Robust Disambiguation of Named Entities in Text*](https://domino.mpi-inf.mpg.de/intranet/ag5/ag5publ.nsf/AuthorEditorIndividualView/058d5590b427985bc12578e70045ebbc/$FILE/aida_emnlp.pdf)
#
# There are two ways of using it:
# 1. let Aida recognize named entity mentions
# 2. pass to Aida already extracted mentions

# %% [markdown]
# ### Helper functions

# %%
def read_iob(filepath):
    """
    A list of strings. Each entry in the list is
    a document from the IOB input.
    """
    data = []
    instance = []
    
    with codecs.open(filepath) as input_file:
        lines = input_file.readlines()
    
    for line in lines:
        
        if line.startswith('#'):
            continue
        
        if line == '\n' and instance:
            data.append(instance)
            instance = []
        elif line == '\n' and not instance:
            pass
        else:
            line = line.replace('\n', '')
            instance.append(tuple(line.split('\t')))
    
    return data

# %%
def iob2text(iob_data):
    texts = []
    for doc in iob_data:
        tokens = [token[1] for token in doc]
        texts.append(" ".join(tokens))
    return texts

# %%
def prepare_aida_input(iob_data):
    """
    list -> list -> dict
    return a list of strings with square brackets around mentions. 
    Each entry in the list is a document from the IOB input.
    """
    prepared_input = ""
    
    for n, token in enumerate(iob_data):
        seq, surface, pos_tag, ne_tag = token
        
        if n - 1 > 0:
            if not iob_data[n-1][-1].startswith('O') and ne_tag == 'O':
                prepared_input += ']]'
        
        if n > 0 and n < len(iob_data):
            prepared_input += " "
        
        if ne_tag.startswith('B-'):
            
            if n - 1 > 0:
                if iob_data[n-1][-1].startswith('B') and ne_tag != 'O':
                    prepared_input += ']]'
            
            prepared_input += f'[[{surface}'
        
        elif ne_tag.startswith('I-'):
            
            prepared_input += f'{surface}'
            
        else:
            prepared_input += (f'{surface}')
    
    return prepared_input

# %% [markdown]
# ### Test with `quaero` data

# %%
iob_data = read_iob('../datasets/quaero/quaero_test_5000_iob.tsv')

# %% [markdown]
# #### Aida does NER

# %% [markdown]
# First test, we let Aida do the NER part (it uses a Stanford tagger trained on English materials):

# %%
# run the code in this cell again (and again)
# to get each time a new (random) document from the quaero dataset

quaero_texts = iob2text(iob_data)
one_random = np.random.choice(quaero_texts)
print(one_random)
# Out:
# Le ministre des finances a soumis au conseil le texte du projet de loi qu' il doit déposer aujourd'hui aux le bureau de la Chambre et qui a pour objet do .

# %% [markdown]
# Now you can copy the text above and paste it into Aida's input text field [here](https://gate.d5.mpi-inf.mpg.de/webaida/).

# %% [markdown]
# #### We do NER, Aida disambiguates

# %%
one_random = np.random.choice(iob_data)
aida_input = prepare_aida_input(one_random)
test_doc = aida_input
print(test_doc)
# Out:
# [[Economiste distingué]] , [[administrateur habile]] , [[M. Ellena]] a fait ses preuves .

# %%
test = [('1', 'A', 'ADP', 'O'),
 ('2', 'la', 'DET', 'O'),
 ('3', 'Chambre', 'NOUN', 'B-org.adm'),
 ('4', ',', 'PUNCT', 'O'),
 ('5', 'M.', 'NOUN', 'B-pers.ind'),
 ('6', 'Constans', 'PROPN', 'I-pers.ind'),
 ('7', 'doit', 'AUX', 'O'),
 ('8', 'répondro', 'VERB', 'O'),
 ('9', "aujourd'hui", 'NOUN', 'B-time.date.rel'),
 ('10', 'a', 'VERB', 'O'),
 ('11', "l'", 'DET', 'O'),
 ('12', 'interpellation', 'NOUN', 'O'),
 ('13', 'du', 'DET', 'O'),
 ('14', 'docteur', 'NOUN', 'B-func.ind'),
 ('15', 'Després', 'ADJ', 'B-pers.ind'),
 ('16', 'sur', 'ADP', 'O'),
 ('17', 'la', 'DET', 'O'),
 ('18', 'laïcisation', 'NOUN', 'O'),
 ('19', 'des', 'DET', 'O'),
 ('20', 'hôpitaux', 'NOUN', 'B-org.ent'),
 ('21', 'do', 'ADP', 'I-org.ent'),
 ('22', 'Paris', 'PROPN', 'I-org.ent'),
 ('23', '.', 'PUNCT', 'O')]

# %%
prepare_aida_input(test)
# Out:
# "A la [[Chambre]] , [[M. Constans]] doit répondro [[aujourd'hui]] a l' interpellation du [[docteur ]][[Després]] sur la laïcisation des [[hôpitaux do Paris]] ."

# %% [markdown]
# Now you can copy the text above and paste it into Aida's input text field here.

# %% [markdown]
# ### Test with `impresso` data

# %%
def load_flair_data():
    
    data_dir = os.path.expanduser('~/datasets/impresso/flair_output/')
    docs = {}
    
    for filename in os.listdir(data_dir):
        if ".json" not in filename:
            continue
        
        with codecs.open(os.path.join(data_dir, filename)) as infile:
            data = json.load(infile)
        docs[filename] = data
        
    print(f'{len(docs)} documents were read from {data_dir}')
    
    return docs

# %%
d = load_flair_data()
# Out:
# 1 documents were read from /home/jovyan/datasets/impresso/flair_output/

# %%
d
# Out:
# {'GDL-1898-08-02-a-i0008.json': [{'text': '— Un journal du matin annonce que le premier coup de pioche pour le percement du Simplon aurait été donné à Briguo lundi matin.',
#    'labels': [],
#    'entities': [{'text': 'Simplon',
#      'start_pos': 81,
#      'end_pos': 88,
#      'type': 'loc.phys.hydro',
#      'confidence': 0.5749263167381287},
#     {'text': 'Briguo',
#      'start_pos': 108,
#      'end_pos': 114,
#      'type': 'loc.adm.town',
#      'confidence': 0.9882785081863403},
#     {'text': 'lundi matin',
#      'start_pos': 115,
#      'end_pos': 126,
#      'type': 'time.date.abs',
#      'confidence': 0.5901570022106171}]},
#   {'text': "Sous celle forme, l'information est inexacte, attendu que le Conseil fédéral n'a pas encore autorisé le commencement des travaux.",
#    'labels': [],
#    'entities': [{'text': 'Conseil fédéral',
#      'start_pos': 61,
#      'end_pos': 76,
#      'type': 'org.adm',
#      'confidence': 0.9232593178749084}]},
#   {'text': 'Il ne pourra le faire que de concert avec le gouvernement italien, et après que celui-ci aura approuvé la justification financière de la compagnie.',
#    'labels': [],
#    'entities': [{'text': 'gouvernement italien',
#      'start_pos': 45,
#      'end_pos': 65,
#      'type': 'org.adm',
#      'confidence': 0.9677907526493073}]},
#   {'text': "Quand ces formalités auront été accomplies, la Direction du Jura-Simplon notifiera à l'entreprise du tunnel l'invitation de commencer les travaux en formité du contrat à forfait passé avec la compagnie, et seulement alors il pourra être question du premier COUD de pioche.",
#    'labels': [],
#    'entities': [{'text': 'Direction du Jura-Simplon',
#      'start_pos': 47,
#      'end_pos': 72,
#      'type': 'org.adm',
#      'confidence': 0.6188924610614777}]},
#   {'text': "— M. Jean Schardt, à Montreux, professeur de géologie à l'académie de Neuchâtel, est nommé géologue de l'entreprise du Simplon.",
#    'labels': [],
#    'entities': [{'text': 'M. Jean Schardt',
#      'start_pos': 2,
#      'end_pos': 17,
#      'type': 'pers.ind',
#      'confidence': 0.8642252162098885},
#     {'text': 'Montreux',
#      'start_pos': 21,
#      'end_pos': 29,
#      'type': 'loc.adm.town',
#      'confidence': 0.9887469410896301},
#     {'text': "professeur de géologie à l'académie de Neuchâtel",
#      'start_pos': 31,
#      'end_pos': 79,
#      'type': 'func.ind',
#      'confidence': 0.7546941297394889},
#     {'text': "géologue de l'entreprise du Simplon",
#      'start_pos': 91,
#      'end_pos': 126,
#      'type': 'func.ind',
#      'confidence': 0.7746869683265686}]},
#   {'text': "— Le Musée a reçu d'une ancienne famille zuricoise un don important.",
#    'labels': [],
#    'entities': [{'text': 'Musée',
#      'start_pos': 5,
#      'end_pos': 10,
#      'type': 'org.ent',
#      'confidence': 0.5976020693778992}]},
#   {'text': "Il s'agit de l'épée et de la médaille données, selon la tradition, par le pape Sixte IV, en 1474, au bourgmestre de Zurich, Henri Roust.",
#    'labels': [],
#    'entities': [{'text': 'pape',
#      'start_pos': 74,
#      'end_pos': 78,
#      'type': 'func.ind',
#      'confidence': 0.9431631565093994},
#     {'text': 'Sixte IV',
#      'start_pos': 79,
#      'end_pos': 87,
#      'type': 'pers.ind',
#      'confidence': 0.9373474419116974},
#     {'text': 'en 1474',
#      'start_pos': 89,
#      'end_pos': 96,
#      'type': 'time.date.abs',
#      'confidence': 0.7515903413295746},
#     {'text': 'bourgmestre de Zurich',
#      'start_pos': 101,
#      'end_pos': 122,
#      'type': 'func.ind',
#      'confidence': 0.7882178823153178},
#     {'text': 'Henri Roust',
#      'start_pos': 124,
#      'end_pos': 135,
#      'type': 'pers.ind',
#      'confidence': 0.97237628698349}]},
#   {'text': 'Le don de la médaille au bourgmestre parait historiquement probable ;',
#    'labels': [],
#    'entities': [{'text': 'bourgmestre',
#      'start_pos': 25,
#      'end_pos': 36,
#      'type': 'func.ind',
#      'confidence': 0.989700198173523}]}]}
